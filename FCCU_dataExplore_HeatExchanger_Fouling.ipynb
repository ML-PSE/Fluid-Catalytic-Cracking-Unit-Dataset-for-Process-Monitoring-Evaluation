# %% [markdown]
# # FCCU Fault Detection and Diagnosis
#
#
# ## Exploring dataset with heat exchanger fouling

# %%
# import packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# package settings
plt.rcParams.update({'font.size': 14})

# %%
# function for lineplots
def lineplot(data, ylabels = None, lw = 0.7, figsize = (15,10),
                  return_fig = False):
        """
        Adapted from: https://github.com/afraniomelo/KydLIB
        
        Purpose
        ----------
        Lineplots of individual variables.
        
        Parameters
        ----------
        data: pandas.DataFrame or numpy.array
            Data that will be plotted
        ylabels: sequence, optional
            Values to use for ylabels. If None, use 1 to n_variables.
        lw: float, optional
            Linewidths.
        figsize: a tuple (width, height) in inches
        return_fig: boolean, optional
            Whether to return the matplotlib.figure.Figure object.          
        """
        
        data = pd.DataFrame(data)
        m = data.shape[1]
        
        if ylabels is None:
            ylabels = range(1,m+1)
        
        n_graph = len(ylabels)
        
        fig, ax = plt.subplots(m, 1, figsize=figsize)
        
        for i in range(n_graph):
            ax[i].plot(data.iloc[:,i].index, 
                       data.iloc[:,i], c='k', linewidth=lw)
            ax[i].set_ylabel(ylabels[i], rotation=0, fontsize=14)
            ax[i].set_yticks([])
            ax[i].spines["top"].set_visible(False)
            ax[i].spines["right"].set_visible(False)
            ax[i].spines["left"].set_visible(False)
            if i<(n_graph-1):
                        ax[i].set_xticks([])
                        ax[i].spines["bottom"].set_visible(False)
                        ax[i].xaxis.set_ticks_position('none')
            else:
                for label in ax[i].get_xticklabels():
                    label.set_rotation(45)
                    label.set_ha('right')
                    
        if return_fig:
            return fig

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       Get Normal Operating Condition Data
###############################################################################

# %%
# stable normal data
FCCU_normal_stable_data = pd.read_csv('NOC_stableFeedFlow_outputs.csv', header=None)
# lineplot(FCCU_normal_stable_data.iloc[:,1:24]) 
# lineplot(FCCU_normal_stable_data.iloc[:,24:], ylabels=np.arange(1,24)+23)

# plot relevant variables
plt.figure(figsize=[5,3])
plt.plot(FCCU_normal_stable_data.iloc[:,1],'seagreen', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F3')
plt.show()

plt.figure(figsize=[5,3])
plt.plot(FCCU_normal_stable_data.iloc[:,28],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F5')
plt.show()

plt.figure(figsize=[5,3])
plt.plot(FCCU_normal_stable_data.iloc[:,8],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('T3')
plt.show()

plt.figure(figsize=[5,3])
plt.plot(FCCU_normal_stable_data.iloc[:,22],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('V1')
plt.show()

# %%
# normal data with varying feed
FCCU_normal_varyingFeed_data = pd.read_csv('NOC_varyingFeedFlow_outputs.csv', header=None)
# lineplot(FCCU_normal_varyingFeed_data.iloc[:,1:24])
# lineplot(FCCU_normal_varyingFeed_data.iloc[:,24:], ylabels=np.arange(1,24)+23)

# plot relevant variables
plt.figure(figsize=[4,2])
plt.plot(FCCU_normal_varyingFeed_data.iloc[:,1],'seagreen', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F3')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_normal_varyingFeed_data.iloc[:,28],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F5')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_normal_varyingFeed_data.iloc[:,8],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('T3')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_normal_varyingFeed_data.iloc[:,22],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('V1')
plt.show()

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       Get Heat Exchanger Fouling Data
###############################################################################

# %%
FCCU_heatX_fouling_data = pd.read_csv('UAf_decrease_outputs.csv', header=None)
# lineplot(FCCU_heatX_fouling_data.iloc[:,1:24])
# lineplot(FCCU_heatX_fouling_data.iloc[:,24:], ylabels=np.arange(1,24)+23)

# plot relevant variables
plt.figure(figsize=[4,2])
plt.plot(FCCU_heatX_fouling_data.iloc[:,1],'seagreen', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F3')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_heatX_fouling_data.iloc[:,28],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('F5')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_heatX_fouling_data.iloc[:,8],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('T3')
plt.show()

plt.figure(figsize=[4,2])
plt.plot(FCCU_heatX_fouling_data.iloc[:,22],'cornflowerblue', linewidth=1)
plt.xlabel('time (mins)')
plt.ylabel('V1')
plt.show()
